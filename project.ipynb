# %%
import pandas as pd
import numpy as np

data = pd.read_csv("dataset.csv")

# %%
data.head()
# Out:
#   Item_Identifier Item_Weight Item_Fat_Content Item_Visibility    Item_Type  \
# 0           FDW58       20.75          Low Fat     0.007564836  Snack Foods
# 1           FDW14         8.3              reg     0.038427677        Dairy
# 2           NCN55        14.6          Low Fat     0.099574908       Others
# 3           FDQ58       7.315          Low Fat     0.015388393  Snack Foods
# 4           FDY38         NaN          Regular     0.118599314        Dairy
#
#    Item_MRP Outlet_Identifier Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                      1999      Medium
# 1   87.3198            OUT017                      2007         NaN
# 2  241.7538            OUT010                      1998         NaN
# 3   155.034            OUT017                      2007         NaN
# 4    234.23            OUT027                      1985      Medium
#
#   Outlet_Location_Type        Outlet_Type Unnamed: 11
# 0               Tier 1  Supermarket Type1         NaN
# 1               Tier 2  Supermarket Type1         NaN
# 2               Tier 3      Grocery Store         NaN
# 3               Tier 2  Supermarket Type1         NaN
# 4               Tier 3  Supermarket Type3         NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14205 entries, 0 to 14204
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14205 non-null  object
#  1   Item_Weight                11766 non-null  object
#  2   Item_Fat_Content           14205 non-null  object
#  3   Item_Visibility            14205 non-null  object
#  4   Item_Type                  14205 non-null  object
#  5   Item_MRP                   14205 non-null  object
#  6   Outlet_Identifier          14205 non-null  object
#  7   Outlet_Establishment_Year  14205 non-null  object
#  8   Outlet_Size                10189 non-null  object
#  9   Outlet_Location_Type       14205 non-null  object
#  10  Outlet_Type                14205 non-null  object
#  11  Unnamed: 11                8524 non-null   object
# dtypes: object(12)
# memory usage: 1.3+ MB

# %%
data['Item_Fat_Content'].value_counts()
# Out:
# Low Fat             8485
# Regular             4824
# LF                   522
# reg                  195
# low fat              178
# Item_Fat_Content       1
# Name: Item_Fat_Content, dtype: int64

# %%
data.apply(lambda x: sum(x.isnull()))
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Unnamed: 11                  5681
# dtype: int64

# %%
data.describe()
# Out:
#        Item_Identifier Item_Weight Item_Fat_Content Item_Visibility  \
# count            14205       11766            14205           14205
# unique            1560         416                6           13007
# top              NCX18        17.6          Low Fat               0
# freq                10         135             8485             879
#
#                     Item_Type  Item_MRP Outlet_Identifier  \
# count                   14205     14205             14205
# unique                     17      8053                11
# top     Fruits and Vegetables  172.0422            OUT027
# freq                     2013         8              1559
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# count                      14205       10189                14205
# unique                        10           4                    4
# top                         1985      Medium               Tier 3
# freq                        2439        4655                 5583
#
#               Outlet_Type Unnamed: 11
# count               14205        8524
# unique                  5        3494
# top     Supermarket Type1     958.752
# freq                 9294          17

# %%
from sklearn.model_selection import train_test_split
train_set, test_set=train_test_split(data, test_size=0.2,random_state=42)
print(f"rows in train set: {len(train_set)}\nrows in test set: {len(test_set)}\n")
# Out:
# rows in train set: 11364
# rows in test set: 2841

# %%
train_set
# Out:
#       Item_Identifier Item_Weight Item_Fat_Content Item_Visibility  \
# 11134           FDG50       7.405          Low Fat     0.015302764
# 3804            FDD11         NaN          Low Fat     0.053605948
# 12273           FDF46         NaN          Low Fat     0.164006137
# 318             FDP52        18.7          Regular               0
# 3611            DRL01        19.5          Regular     0.077328827
# ...               ...         ...              ...             ...
# 5191            FDQ47         NaN          Regular     0.167371926
# 13418           FDW16       17.35          Regular     0.041474232
# 5390            FDB10          10          Low Fat     0.067152194
# 860             FDS07       12.35               LF      0.09991293
# 7270            FDD16         NaN          Low Fat     0.063649582
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 11134                 Canned   89.9146            OUT045
# 3804           Starchy Foods   252.404            OUT019
# 12273            Snack Foods  113.2834            OUT019
# 318             Frozen Foods   231.201            OUT045
# 3611             Soft Drinks  233.5958            OUT045
# ...                      ...       ...               ...
# 5191                  Breads   36.4874            OUT027
# 13418           Frozen Foods   93.0804            OUT046
# 5390             Snack Foods   237.259            OUT013
# 860    Fruits and Vegetables  113.4518            OUT049
# 7270            Frozen Foods   74.7696            OUT019
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 11134                      2002         NaN               Tier 2
# 3804                       1985       Small               Tier 1
# 12273                      1985       Small               Tier 1
# 318                        2002         NaN               Tier 2
# 3611                       2002         NaN               Tier 2
# ...                         ...         ...                  ...
# 5191                       1985      Medium               Tier 3
# 13418                      1997       Small               Tier 1
# 5390                       1987        High               Tier 3
# 860                        1999      Medium               Tier 1
# 7270                       1985       Small               Tier 1
#
#              Outlet_Type Unnamed: 11
# 11134  Supermarket Type1   2189.1504
# 3804       Grocery Store         NaN
# 12273      Grocery Store     575.917
# 318    Supermarket Type1         NaN
# 3611   Supermarket Type1         NaN
# ...                  ...         ...
# 5191   Supermarket Type3         NaN
# 13418  Supermarket Type1    826.9236
# 5390   Supermarket Type1         NaN
# 860    Supermarket Type1         NaN
# 7270       Grocery Store     74.5696
#
# [11364 rows x 12 columns]

# %%
train_set.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
